# %% [markdown]
# <a href="https://colab.research.google.com/github/maoproYT/PROGCOM-A/blob/main/CQ1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Los siguientes "pantallazos" corresponden al CQ1, donde se han hecho todos los niveles, incluyendo los de pago

# %% [markdown]
# ![Code_Combat1.jpeg](data:image/jpeg;base64,...)![Code_Combat_Mundo2.jpeg](data:image/jpeg;base64,...)
