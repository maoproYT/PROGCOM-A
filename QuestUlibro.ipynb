# %% [markdown]
# <a href="https://colab.research.google.com/github/maoproYT/PROGCOM-A/blob/main/QuestUlibro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ética en el uso de la inteligencia artificial en bibliotecas
# ##Los 5 elementos más relevantes sobre los que trató la presentación fueron:
# (1)los beneficios éticos de la IA, la eficiencia, la reducción de errores humanos y como las capacidades análiticas de la misma pueden ayudar a automatizar tareas tediosas.
# (2)Las teorias éticas desarrolladas para la IA, las cuales deben basarse según el contexto social  y geografico. Además, debe tener en cuenta elements como el momento histórico en el que ocurren.
# (3)Las leyes de Asimov: ya que relatan las normas basícas que debe cumplir toda IA, como no causar bajo ninguna circunstancia dolor a alguna persona, obedecer las ordenes humanas siempre que estas no incumplan la primera y por último que el robot debe perpetuar su existencia al menos que esta incumpla con alguna de las normas ya mencionadas.
# (4)el uso responsable de la IA, promover alfabetización en datos y algoritmos, y abogar por regulaciones éticas y responsables, ya que por medio de estas es posible crear un concenso común sobre el uso que debería de tener.
# (5)Como las personas han buscado una forma en la que la IA sea más "humano". Sin embargo, se cometen contradicciones al realizar estas dinámicas.

# %% [markdown]
# ![WhatsApp Image 2025-08-26 at 10.30.44 PM.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2025-08-26 at 10.02.30 PM.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2025-08-26 at 10.30.44 PM (1).jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2025-08-26 at 10.30.45 PM.jpeg](data:image/jpeg;base64,...)![WhatsApp Image 2025-08-26 at 10.30.44 PM (2).jpeg](data:image/jpeg;base64,...)
