# %% [markdown]
# <a href="https://colab.research.google.com/github/maoproYT/PROGCOM-A/blob/main/CQ6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Captura de pantalla 2025-09-26 120329.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-09-26 122212.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-09-26 124215.png](data:image/png;base64,...)
