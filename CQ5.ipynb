# %% [markdown]
# <a href="https://colab.research.google.com/github/maoproYT/PROGCOM-A/blob/main/CQ5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Captura de pantalla 2025-10-20 220502.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-10-20 220238.png](data:image/png;base64,...)
