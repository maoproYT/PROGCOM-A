# %% [markdown]
# <a href="https://colab.research.google.com/github/maoproYT/PROGCOM-A/blob/main/CQ9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Add blockquote![CQ9.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de pantalla 2025-09-26 122018.png](data:image/png;base64,...)
